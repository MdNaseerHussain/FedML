# %% [markdown]
# # Federated ML
# ## Contents
# 1. Introduction
# 2. Reading an image from the dataset
# 3. Loading Images and Labels
# 4. Splitting training and testing data
# 5. Creating clients
# 6. Batching clients' and test data
# 7. Creating an MLP model
# 8. Optimizer, Loss function and Metrics to compile the model
# 9. Utility functions for the Federated Averaging
# 10. Model test function
# 11. Federated Averaging Algorithm

# %% [markdown]
# ## Introduction
# In this notebook, we have implemented i working Federated ML model. The goal is to simulate packet losses in communication between the server and the clients in the Federated Averaging Algorithm. The function once implemented will be added to the algorithm near the TODO's in the code.

# %% [markdown]
# Reading an image from the dataset

# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread("datasets/numbers/trainingSet/0/img_1.jpg")
plt.imshow(image)
plt.title("Image")
# Out:
# Text(0.5, 1.0, 'Image')

# %% [markdown]
# Loading Images and Labels

# %%
import os
import numpy as np
from sklearn.preprocessing import LabelBinarizer
dir_path = "datasets/numbers/trainingSet/"
images = list()
labels = list()
for number in range(0, 10):
    folder = dir_path + str(number)
    for image_file in os.listdir(folder):
        image_gray = cv2.imread(os.path.join(folder, image_file), cv2.IMREAD_GRAYSCALE)
        image = np.array(image_gray).flatten()
        images.append(image/255)
        labels.append(number)
    print("[INFO] Processed {}/{}".format(number + 1, 10))
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
# Out:
# [INFO] Processed 1/10
# [INFO] Processed 2/10
# [INFO] Processed 3/10
# [INFO] Processed 4/10
# [INFO] Processed 5/10
# [INFO] Processed 6/10
# [INFO] Processed 7/10
# [INFO] Processed 8/10
# [INFO] Processed 9/10
# [INFO] Processed 10/10

# %% [markdown]
# Splitting training and testing data

# %%
from sklearn.model_selection import train_test_split
images_train, images_test, labels_train, labels_test = train_test_split(images, labels, test_size=0.1, random_state=42)

# %% [markdown]
# Creating clients

# %%
import random
num_clients = 10
client_names = ["client_{}".format(i + 1) for i in range(num_clients)]
data = list(zip(images, labels))
random.shuffle(data)
size = len(data)//num_clients
data_shards = [data[i:i + size] for i in range(0, size*num_clients, size)]
clients = {client_names[i]: data_shards[i] for i in range(num_clients)}

# %% [markdown]
# Batching clients' and test data

# %%
import tensorflow as tf
batch_size = 32
clients_batched = dict()
for (client_name, data_shard) in clients.items():
    data, labels = zip(*data_shard)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(labels)))
    clients_batched[client_name] = dataset.shuffle(len(labels)).batch(batch_size)
test_batched = tf.data.Dataset.from_tensor_slices((images_test, labels_test)).batch(len(labels_test))

# %% [markdown]
# Creating the Multi Layer Perception (MLP) model

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
class SimpleMLP:
    @staticmethod
    def build(shape, classes):
        model = Sequential()
        model.add(Dense(200, input_shape=(shape,)))
        model.add(Activation("relu"))
        model.add(Dense(200))
        model.add(Activation("relu"))
        model.add(Dense(classes))
        model.add(Activation("softmax"))
        return model

# %% [markdown]
# Optimizer, Loss function and Metrics to compile the model

# %%
from keras.optimizers import SGD
lr = 0.01 
comms_round = 100
loss='categorical_crossentropy'
metrics = ['accuracy']
optimizer = SGD(lr=lr, decay=lr/comms_round, momentum=0.9)
# Out:
# c:\Users\mdnaj\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# Utility functions for the Federated Averaging

# %%
def weight_scaling_factor(clients_trn_data, client_name):
    client_names = list(clients_trn_data.keys())
    bs = list(clients_trn_data[client_name])[0][0].shape[0]
    global_count = sum([tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy() for client_name in client_names])*bs
    local_count = tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy()*bs
    return local_count/global_count


def scale_model_weights(weight, scalar):
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final


def sum_scaled_weights(scaled_weight_list):
    avg_grad = list()
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)
    return avg_grad

# %% [markdown]
# Functions to fetch and set shape of model weights

# %%
def get_shape(weights):
    shapes = [i.shape for i in weights]
    return shapes

def flatten_model_weights(weights):
    flattened_weights = np.concatenate([i.flatten() for i in weights])
    return flattened_weights

def restore_model_shape(flattened_weights, shapes):
    weights = []
    index = 0
    for shape in shapes:
        size = np.product(shape)
        arr = np.array(flattened_weights[index : index + size])
        weights.append(arr.reshape(shape))
        index += size
    return weights

# %% [markdown]
# Modulation and Demodulation Functions for Communication

# %%
from bitstring import BitArray
import random

def modulation(weights):
    weights = flatten_model_weights(weights)
    packets = []
    for i in range(len(weights)):
        packet = BitArray(float=weights[i], length=32)
        packets.append(packet.bin)
    return packets

def demodulation(packets, packet_loss_prob, model_shape):
    weights = packets
    for i in range(len(packets)):
        weight = BitArray(bin=packets[i])
        if random.random() < packet_loss_prob:
            weights[i] = 0
        else:
            weights[i] = weight.float
    return restore_model_shape(weights, model_shape)

# %% [markdown]
# Model test function

# %%
from keras.losses import CategoricalCrossentropy
from sklearn.metrics import accuracy_score
def test_model(X_test, Y_test,  model, comm_round):
    cce = CategoricalCrossentropy(from_logits=True)
    logits = model.predict(X_test)
    loss = cce(Y_test, logits)
    acc = accuracy_score(tf.argmax(logits, axis=1), tf.argmax(Y_test, axis=1))
    print('comm_round: {} | global_acc: {:.3%} | global_loss: {}'.format(comm_round+1, acc, loss))
    return acc, loss

# %% [markdown]
# Federated Averaging Algorithm

# %%
from keras import backend as K
def fedML(packet_loss_prob):
    smlp_global = SimpleMLP()
    global_model = smlp_global.build(784, 10)
    model_shape = get_shape(global_model.get_weights())
    accuracy = []
    for comm_round in range(comms_round):
        global_weights = global_model.get_weights()
        scaled_local_weight_list = list()
        client_names= list(clients_batched.keys())
        random.shuffle(client_names)
        for client in client_names:
            smlp_local = SimpleMLP()
            local_model = smlp_local.build(784, 10)
            local_model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
            local_model.set_weights(global_weights)
            local_model.fit(clients_batched[client], epochs=1, verbose=0)
            scaling_factor = weight_scaling_factor(clients_batched, client)
            scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
            packets = modulation(scaled_weights)
            new_weights = demodulation(packets, packet_loss_prob, model_shape)
            scaled_local_weight_list.append(new_weights)
            K.clear_session()
        average_weights = sum_scaled_weights(scaled_local_weight_list)
        global_model.set_weights(average_weights)
        for(X_test, Y_test) in test_batched:
            global_acc, global_loss = test_model(X_test, Y_test, global_model, comm_round)
            accuracy.append(global_acc)
    return accuracy

# %%
errors = [0, 0.01, 0.05, 0.1]
accuracies = []
for error in errors:
    accuracies.append(fedML(error))
    print("{}".format(error))
# Out:
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 1 | global_acc: 88.786% | global_loss: 1.6624020338058472
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 2 | global_acc: 91.214% | global_loss: 1.6090692281723022
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 3 | global_acc: 92.286% | global_loss: 1.5902550220489502
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 4 | global_acc: 93.476% | global_loss: 1.5772944688796997
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 5 | global_acc: 93.690% | global_loss: 1.56877863407135
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 6 | global_acc: 94.095% | global_loss: 1.5603489875793457
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 7 | global_acc: 94.571% | global_loss: 1.5549336671829224
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 8 | global_acc: 94.929% | global_loss: 1.5499669313430786
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 9 | global_acc: 95.167% | global_loss: 1.5454438924789429
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 10 | global_acc: 95.310% | global_loss: 1.5425699949264526
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 11 | global_acc: 95.548% | global_loss: 1.539623737335205
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 12 | global_acc: 95.690% | global_loss: 1.5370410680770874
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 13 | global_acc: 95.762% | global_loss: 1.534979224205017
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 14 | global_acc: 96.071% | global_loss: 1.5320758819580078
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 15 | global_acc: 96.071% | global_loss: 1.5305370092391968
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 16 | global_acc: 96.190% | global_loss: 1.529142141342163
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 17 | global_acc: 96.119% | global_loss: 1.5268833637237549
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 18 | global_acc: 96.262% | global_loss: 1.5258045196533203
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 19 | global_acc: 96.310% | global_loss: 1.5244135856628418
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 20 | global_acc: 96.452% | global_loss: 1.5229392051696777
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 21 | global_acc: 96.524% | global_loss: 1.5217348337173462
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 22 | global_acc: 96.500% | global_loss: 1.5206937789916992
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 23 | global_acc: 96.690% | global_loss: 1.5197972059249878
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 24 | global_acc: 96.667% | global_loss: 1.5190176963806152
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 25 | global_acc: 96.595% | global_loss: 1.5182329416275024
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 26 | global_acc: 96.810% | global_loss: 1.5173890590667725
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 27 | global_acc: 96.929% | global_loss: 1.516391396522522
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 28 | global_acc: 97.000% | global_loss: 1.515552282333374
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 29 | global_acc: 97.143% | global_loss: 1.5148698091506958
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 30 | global_acc: 97.095% | global_loss: 1.5144761800765991
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 31 | global_acc: 97.095% | global_loss: 1.5137219429016113
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 32 | global_acc: 97.214% | global_loss: 1.5131314992904663
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 33 | global_acc: 97.286% | global_loss: 1.5124506950378418
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 34 | global_acc: 97.262% | global_loss: 1.5121601819992065
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 35 | global_acc: 97.310% | global_loss: 1.5117532014846802
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 36 | global_acc: 97.357% | global_loss: 1.5111321210861206
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 37 | global_acc: 97.357% | global_loss: 1.5109329223632812
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 38 | global_acc: 97.429% | global_loss: 1.510148286819458
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 39 | global_acc: 97.381% | global_loss: 1.5097970962524414
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 40 | global_acc: 97.476% | global_loss: 1.5092254877090454
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 41 | global_acc: 97.405% | global_loss: 1.508829951286316
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 42 | global_acc: 97.524% | global_loss: 1.5085707902908325
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 43 | global_acc: 97.524% | global_loss: 1.5081368684768677
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 44 | global_acc: 97.595% | global_loss: 1.507808804512024
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 45 | global_acc: 97.595% | global_loss: 1.5073442459106445
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 46 | global_acc: 97.643% | global_loss: 1.507174015045166
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 47 | global_acc: 97.643% | global_loss: 1.506833553314209
# 132/132 [==============================] - 0s 2ms/step
# comm_round: 48 | global_acc: 97.619% | global_loss: 1.5063416957855225
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 49 | global_acc: 97.667% | global_loss: 1.505968689918518
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 50 | global_acc: 97.714% | global_loss: 1.5056824684143066
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 51 | global_acc: 97.762% | global_loss: 1.5056689977645874
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 52 | global_acc: 97.738% | global_loss: 1.505478024482727
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 53 | global_acc: 97.762% | global_loss: 1.5049527883529663
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 54 | global_acc: 97.833% | global_loss: 1.5048458576202393
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 55 | global_acc: 97.786% | global_loss: 1.5045491456985474
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 56 | global_acc: 97.762% | global_loss: 1.5039962530136108
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 57 | global_acc: 97.786% | global_loss: 1.5037318468093872
# 132/132 [==============================] - 1s 6ms/step
# comm_round: 58 | global_acc: 97.833% | global_loss: 1.5037267208099365
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 59 | global_acc: 97.905% | global_loss: 1.5034191608428955
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 60 | global_acc: 97.881% | global_loss: 1.5030080080032349
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 61 | global_acc: 97.881% | global_loss: 1.503017544746399
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 62 | global_acc: 97.905% | global_loss: 1.5027765035629272
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 63 | global_acc: 97.929% | global_loss: 1.5025618076324463
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 64 | global_acc: 97.881% | global_loss: 1.502314805984497
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 65 | global_acc: 97.929% | global_loss: 1.502172589302063
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 66 | global_acc: 97.905% | global_loss: 1.50190269947052
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 67 | global_acc: 97.952% | global_loss: 1.5016893148422241
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 68 | global_acc: 97.952% | global_loss: 1.5015076398849487
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 69 | global_acc: 98.000% | global_loss: 1.501366138458252
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 70 | global_acc: 97.976% | global_loss: 1.5010788440704346
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 71 | global_acc: 98.000% | global_loss: 1.5008701086044312
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 72 | global_acc: 97.976% | global_loss: 1.500754952430725
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 73 | global_acc: 98.000% | global_loss: 1.5006169080734253
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 74 | global_acc: 98.000% | global_loss: 1.5003585815429688
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 75 | global_acc: 98.000% | global_loss: 1.500249981880188
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 76 | global_acc: 97.976% | global_loss: 1.4999942779541016
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 77 | global_acc: 98.024% | global_loss: 1.4998209476470947
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 78 | global_acc: 98.000% | global_loss: 1.499856948852539
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 79 | global_acc: 98.024% | global_loss: 1.4995449781417847
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 80 | global_acc: 98.048% | global_loss: 1.4995198249816895
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 81 | global_acc: 98.024% | global_loss: 1.4993358850479126
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 82 | global_acc: 98.048% | global_loss: 1.4991093873977661
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 83 | global_acc: 98.024% | global_loss: 1.4989869594573975
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 84 | global_acc: 98.024% | global_loss: 1.498885989189148
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 85 | global_acc: 98.048% | global_loss: 1.4986861944198608
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 86 | global_acc: 98.048% | global_loss: 1.4986207485198975
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 87 | global_acc: 98.119% | global_loss: 1.4983900785446167
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 88 | global_acc: 98.119% | global_loss: 1.4983073472976685
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 89 | global_acc: 98.048% | global_loss: 1.4983088970184326
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 90 | global_acc: 98.095% | global_loss: 1.498063325881958
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 91 | global_acc: 98.143% | global_loss: 1.4978212118148804
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 92 | global_acc: 98.095% | global_loss: 1.4977694749832153
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 93 | global_acc: 98.095% | global_loss: 1.4977084398269653
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 94 | global_acc: 98.167% | global_loss: 1.4976074695587158
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 95 | global_acc: 98.167% | global_loss: 1.497398853302002
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 96 | global_acc: 98.119% | global_loss: 1.4971847534179688
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 97 | global_acc: 98.119% | global_loss: 1.4971811771392822
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 98 | global_acc: 98.119% | global_loss: 1.497068166732788
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 99 | global_acc: 98.167% | global_loss: 1.4969091415405273
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 100 | global_acc: 98.167% | global_loss: 1.4968034029006958
# 0
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 1 | global_acc: 56.643% | global_loss: 2.2454543113708496
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 2 | global_acc: 72.476% | global_loss: 2.146024465560913
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 3 | global_acc: 79.024% | global_loss: 2.019420623779297
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 4 | global_acc: 82.452% | global_loss: 1.9210883378982544
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 5 | global_acc: 84.048% | global_loss: 1.852292537689209
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 6 | global_acc: 85.500% | global_loss: 1.8088611364364624
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 7 | global_acc: 86.238% | global_loss: 1.776407241821289
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 8 | global_acc: 86.929% | global_loss: 1.7541749477386475
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 9 | global_acc: 87.619% | global_loss: 1.7363032102584839
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 10 | global_acc: 87.738% | global_loss: 1.721816897392273
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 11 | global_acc: 88.167% | global_loss: 1.711378812789917
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 12 | global_acc: 88.500% | global_loss: 1.7023261785507202
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 13 | global_acc: 88.810% | global_loss: 1.6955492496490479
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 14 | global_acc: 88.762% | global_loss: 1.689813256263733
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 15 | global_acc: 89.143% | global_loss: 1.6847079992294312
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 16 | global_acc: 89.333% | global_loss: 1.6802897453308105
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 17 | global_acc: 89.238% | global_loss: 1.6759918928146362
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 18 | global_acc: 89.690% | global_loss: 1.6733005046844482
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 19 | global_acc: 89.667% | global_loss: 1.6709328889846802
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 20 | global_acc: 89.857% | global_loss: 1.667460560798645
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 21 | global_acc: 90.024% | global_loss: 1.6656275987625122
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 22 | global_acc: 90.190% | global_loss: 1.6629759073257446
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 23 | global_acc: 90.238% | global_loss: 1.661566972732544
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 24 | global_acc: 90.310% | global_loss: 1.6588420867919922
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 25 | global_acc: 90.619% | global_loss: 1.657279133796692
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 26 | global_acc: 90.429% | global_loss: 1.6555417776107788
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 27 | global_acc: 90.333% | global_loss: 1.6547300815582275
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 28 | global_acc: 90.286% | global_loss: 1.6537340879440308
# 132/132 [==============================] - 1s 8ms/step
# comm_round: 29 | global_acc: 90.333% | global_loss: 1.6530649662017822
# 132/132 [==============================] - 1s 6ms/step
# comm_round: 30 | global_acc: 90.643% | global_loss: 1.653489112854004
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 31 | global_acc: 90.786% | global_loss: 1.6516785621643066
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 32 | global_acc: 90.786% | global_loss: 1.6510357856750488
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 33 | global_acc: 90.929% | global_loss: 1.6508769989013672
# 132/132 [==============================] - 1s 6ms/step
# comm_round: 34 | global_acc: 90.595% | global_loss: 1.650174617767334
# 132/132 [==============================] - 1s 8ms/step
# comm_round: 35 | global_acc: 91.000% | global_loss: 1.6504731178283691
# 132/132 [==============================] - 1s 7ms/step
# comm_round: 36 | global_acc: 90.952% | global_loss: 1.6496493816375732
# 132/132 [==============================] - 1s 8ms/step
# comm_round: 37 | global_acc: 91.024% | global_loss: 1.6493726968765259
# 132/132 [==============================] - 1s 7ms/step
# comm_round: 38 | global_acc: 90.929% | global_loss: 1.648977518081665
# 132/132 [==============================] - 1s 7ms/step
# comm_round: 39 | global_acc: 91.262% | global_loss: 1.6492165327072144
# 132/132 [==============================] - 3s 18ms/step
# comm_round: 40 | global_acc: 91.071% | global_loss: 1.6480218172073364
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 41 | global_acc: 91.190% | global_loss: 1.6476701498031616
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 42 | global_acc: 91.238% | global_loss: 1.6484051942825317
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 43 | global_acc: 91.405% | global_loss: 1.6481282711029053
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 44 | global_acc: 91.405% | global_loss: 1.6490938663482666
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 45 | global_acc: 91.452% | global_loss: 1.6481986045837402
# 132/132 [==============================] - 1s 9ms/step
# comm_round: 46 | global_acc: 91.381% | global_loss: 1.6487406492233276
# 132/132 [==============================] - 0s 3ms/step
# comm_round: 47 | global_acc: 91.476% | global_loss: 1.6490038633346558
# 132/132 [==============================] - 1s 10ms/step
# comm_round: 48 | global_acc: 91.333% | global_loss: 1.6486951112747192
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 49 | global_acc: 91.381% | global_loss: 1.6489156484603882
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 50 | global_acc: 91.571% | global_loss: 1.6489287614822388
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 51 | global_acc: 91.643% | global_loss: 1.6493737697601318
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 52 | global_acc: 91.667% | global_loss: 1.648945689201355
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 53 | global_acc: 91.571% | global_loss: 1.6492160558700562
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 54 | global_acc: 91.714% | global_loss: 1.6495648622512817
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 55 | global_acc: 91.595% | global_loss: 1.650506615638733
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 56 | global_acc: 91.619% | global_loss: 1.6501576900482178
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 57 | global_acc: 91.810% | global_loss: 1.6507542133331299
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 58 | global_acc: 91.619% | global_loss: 1.651563048362732
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 59 | global_acc: 91.690% | global_loss: 1.651649832725525
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 60 | global_acc: 91.833% | global_loss: 1.6509425640106201
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 61 | global_acc: 91.595% | global_loss: 1.651482105255127
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 62 | global_acc: 91.762% | global_loss: 1.651718020439148
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 63 | global_acc: 91.762% | global_loss: 1.6516047716140747
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 64 | global_acc: 91.762% | global_loss: 1.6515668630599976
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 65 | global_acc: 91.595% | global_loss: 1.6518396139144897
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 66 | global_acc: 91.786% | global_loss: 1.652148962020874
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 67 | global_acc: 91.643% | global_loss: 1.6522051095962524
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 68 | global_acc: 91.738% | global_loss: 1.651894450187683
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 69 | global_acc: 91.714% | global_loss: 1.6527838706970215
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 70 | global_acc: 91.714% | global_loss: 1.652678370475769
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 71 | global_acc: 91.690% | global_loss: 1.6536964178085327
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 72 | global_acc: 91.643% | global_loss: 1.6545839309692383
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 73 | global_acc: 91.762% | global_loss: 1.6542973518371582
# 132/132 [==============================] - 1s 3ms/step
# comm_round: 74 | global_acc: 91.667% | global_loss: 1.654657006263733
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 75 | global_acc: 91.714% | global_loss: 1.6552832126617432
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 76 | global_acc: 91.762% | global_loss: 1.654957890510559
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 77 | global_acc: 91.810% | global_loss: 1.655881404876709
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 78 | global_acc: 91.857% | global_loss: 1.6568503379821777
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 79 | global_acc: 91.762% | global_loss: 1.6567988395690918
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 80 | global_acc: 91.738% | global_loss: 1.656807541847229
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 81 | global_acc: 91.643% | global_loss: 1.6569682359695435
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 82 | global_acc: 91.714% | global_loss: 1.6579939126968384
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 83 | global_acc: 91.690% | global_loss: 1.658008337020874
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 84 | global_acc: 91.810% | global_loss: 1.6581926345825195
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 85 | global_acc: 91.786% | global_loss: 1.6584876775741577
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 86 | global_acc: 91.810% | global_loss: 1.6590404510498047
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 87 | global_acc: 91.786% | global_loss: 1.6593036651611328
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 88 | global_acc: 91.690% | global_loss: 1.6590219736099243
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 89 | global_acc: 91.690% | global_loss: 1.6587848663330078
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 90 | global_acc: 91.619% | global_loss: 1.6598156690597534
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 91 | global_acc: 91.714% | global_loss: 1.6599574089050293
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 92 | global_acc: 91.714% | global_loss: 1.660961627960205
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 93 | global_acc: 91.714% | global_loss: 1.6613810062408447
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 94 | global_acc: 91.762% | global_loss: 1.6613599061965942
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 95 | global_acc: 91.667% | global_loss: 1.6622412204742432
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 96 | global_acc: 91.786% | global_loss: 1.6624337434768677
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 97 | global_acc: 91.667% | global_loss: 1.6621801853179932
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 98 | global_acc: 91.667% | global_loss: 1.6629951000213623
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 99 | global_acc: 91.452% | global_loss: 1.66386878490448
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 100 | global_acc: 91.786% | global_loss: 1.6645002365112305
# 0.01
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 1 | global_acc: 44.619% | global_loss: 2.273530960083008
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 2 | global_acc: 62.810% | global_loss: 2.2435898780822754
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 3 | global_acc: 69.071% | global_loss: 2.2136127948760986
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 4 | global_acc: 73.310% | global_loss: 2.1823370456695557
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 5 | global_acc: 75.738% | global_loss: 2.1543002128601074
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 6 | global_acc: 77.738% | global_loss: 2.1305065155029297
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 7 | global_acc: 78.476% | global_loss: 2.106945753097534
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 8 | global_acc: 79.381% | global_loss: 2.089510440826416
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 9 | global_acc: 79.738% | global_loss: 2.0741307735443115
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 10 | global_acc: 80.143% | global_loss: 2.0612120628356934
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 11 | global_acc: 81.357% | global_loss: 2.0530402660369873
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 12 | global_acc: 80.905% | global_loss: 2.047159433364868
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 13 | global_acc: 81.786% | global_loss: 2.0428054332733154
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 14 | global_acc: 81.643% | global_loss: 2.0398805141448975
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 15 | global_acc: 81.881% | global_loss: 2.038076400756836
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 16 | global_acc: 81.548% | global_loss: 2.0362281799316406
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 17 | global_acc: 81.762% | global_loss: 2.0354347229003906
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 18 | global_acc: 79.738% | global_loss: 2.0328519344329834
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 19 | global_acc: 81.238% | global_loss: 2.0332369804382324
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 20 | global_acc: 81.071% | global_loss: 2.033794641494751
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 21 | global_acc: 80.595% | global_loss: 2.0346391201019287
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 22 | global_acc: 81.310% | global_loss: 2.036144971847534
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 23 | global_acc: 80.381% | global_loss: 2.0344185829162598
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 24 | global_acc: 80.952% | global_loss: 2.03645920753479
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 25 | global_acc: 80.786% | global_loss: 2.039196252822876
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 26 | global_acc: 80.571% | global_loss: 2.03790545463562
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 27 | global_acc: 80.905% | global_loss: 2.0398926734924316
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 28 | global_acc: 80.190% | global_loss: 2.039691925048828
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 29 | global_acc: 80.476% | global_loss: 2.0426580905914307
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 30 | global_acc: 79.119% | global_loss: 2.042210578918457
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 31 | global_acc: 79.738% | global_loss: 2.0441389083862305
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 32 | global_acc: 79.976% | global_loss: 2.046137809753418
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 33 | global_acc: 79.667% | global_loss: 2.047017812728882
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 34 | global_acc: 79.071% | global_loss: 2.046840190887451
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 35 | global_acc: 79.571% | global_loss: 2.050133228302002
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 36 | global_acc: 78.643% | global_loss: 2.0507454872131348
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 37 | global_acc: 78.690% | global_loss: 2.0523629188537598
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 38 | global_acc: 79.167% | global_loss: 2.0551557540893555
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 39 | global_acc: 79.262% | global_loss: 2.056514263153076
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 40 | global_acc: 79.119% | global_loss: 2.056180715560913
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 41 | global_acc: 78.262% | global_loss: 2.056898355484009
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 42 | global_acc: 78.524% | global_loss: 2.0595474243164062
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 43 | global_acc: 77.405% | global_loss: 2.0601603984832764
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 44 | global_acc: 77.714% | global_loss: 2.0621795654296875
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 45 | global_acc: 77.119% | global_loss: 2.062042474746704
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 46 | global_acc: 77.833% | global_loss: 2.0663561820983887
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 47 | global_acc: 77.881% | global_loss: 2.0670716762542725
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 48 | global_acc: 77.452% | global_loss: 2.0683631896972656
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 49 | global_acc: 77.429% | global_loss: 2.068472146987915
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 50 | global_acc: 77.095% | global_loss: 2.070547342300415
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 51 | global_acc: 76.952% | global_loss: 2.070704698562622
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 52 | global_acc: 76.905% | global_loss: 2.071320056915283
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 53 | global_acc: 76.524% | global_loss: 2.071223258972168
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 54 | global_acc: 76.881% | global_loss: 2.073629140853882
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 55 | global_acc: 76.810% | global_loss: 2.075427532196045
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 56 | global_acc: 76.762% | global_loss: 2.0770814418792725
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 57 | global_acc: 76.238% | global_loss: 2.079009532928467
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 58 | global_acc: 75.429% | global_loss: 2.080977439880371
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 59 | global_acc: 75.595% | global_loss: 2.0819013118743896
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 60 | global_acc: 75.810% | global_loss: 2.0835719108581543
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 61 | global_acc: 74.833% | global_loss: 2.082221508026123
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 62 | global_acc: 75.500% | global_loss: 2.0847020149230957
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 63 | global_acc: 74.905% | global_loss: 2.084852695465088
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 64 | global_acc: 75.357% | global_loss: 2.0869810581207275
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 65 | global_acc: 74.881% | global_loss: 2.088153839111328
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 66 | global_acc: 74.881% | global_loss: 2.089043378829956
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 67 | global_acc: 74.048% | global_loss: 2.089613914489746
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 68 | global_acc: 72.905% | global_loss: 2.090481758117676
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 69 | global_acc: 74.024% | global_loss: 2.092139959335327
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 70 | global_acc: 74.286% | global_loss: 2.0947248935699463
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 71 | global_acc: 73.500% | global_loss: 2.094680070877075
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 72 | global_acc: 73.905% | global_loss: 2.0950088500976562
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 73 | global_acc: 73.643% | global_loss: 2.096090793609619
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 74 | global_acc: 73.190% | global_loss: 2.0964040756225586
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 75 | global_acc: 72.952% | global_loss: 2.0971503257751465
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 76 | global_acc: 73.048% | global_loss: 2.100294351577759
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 77 | global_acc: 73.262% | global_loss: 2.1027634143829346
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 78 | global_acc: 72.238% | global_loss: 2.1017699241638184
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 79 | global_acc: 72.429% | global_loss: 2.1029441356658936
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 80 | global_acc: 71.881% | global_loss: 2.104210376739502
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 81 | global_acc: 72.262% | global_loss: 2.106041431427002
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 82 | global_acc: 72.548% | global_loss: 2.1077961921691895
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 83 | global_acc: 72.024% | global_loss: 2.106884717941284
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 84 | global_acc: 71.048% | global_loss: 2.1063897609710693
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 85 | global_acc: 71.595% | global_loss: 2.108433485031128
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 86 | global_acc: 70.762% | global_loss: 2.109351396560669
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 87 | global_acc: 71.143% | global_loss: 2.1102898120880127
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 88 | global_acc: 71.333% | global_loss: 2.1130435466766357
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 89 | global_acc: 71.452% | global_loss: 2.114683151245117
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 90 | global_acc: 70.952% | global_loss: 2.1166293621063232
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 91 | global_acc: 70.881% | global_loss: 2.114914894104004
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 92 | global_acc: 70.524% | global_loss: 2.115704298019409
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 93 | global_acc: 70.262% | global_loss: 2.1146438121795654
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 94 | global_acc: 70.048% | global_loss: 2.115675687789917
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 95 | global_acc: 69.524% | global_loss: 2.1160428524017334
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 96 | global_acc: 68.810% | global_loss: 2.117332696914673
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 97 | global_acc: 69.024% | global_loss: 2.1187729835510254
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 98 | global_acc: 68.810% | global_loss: 2.1196250915527344
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 99 | global_acc: 69.714% | global_loss: 2.1220438480377197
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 100 | global_acc: 69.048% | global_loss: 2.1232779026031494
# 0.05
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 1 | global_acc: 31.333% | global_loss: 2.2917141914367676
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 2 | global_acc: 52.929% | global_loss: 2.284787654876709
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 3 | global_acc: 60.857% | global_loss: 2.281949758529663
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 4 | global_acc: 63.952% | global_loss: 2.280860185623169
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 5 | global_acc: 68.333% | global_loss: 2.2811365127563477
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 6 | global_acc: 67.976% | global_loss: 2.2818195819854736
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 7 | global_acc: 68.976% | global_loss: 2.2835652828216553
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 8 | global_acc: 68.357% | global_loss: 2.28560733795166
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 9 | global_acc: 68.238% | global_loss: 2.2877609729766846
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 10 | global_acc: 69.095% | global_loss: 2.2896955013275146
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 11 | global_acc: 67.976% | global_loss: 2.2915244102478027
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 12 | global_acc: 67.071% | global_loss: 2.293198823928833
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 13 | global_acc: 65.905% | global_loss: 2.2945668697357178
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 14 | global_acc: 63.786% | global_loss: 2.2959697246551514
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 15 | global_acc: 60.238% | global_loss: 2.2971279621124268
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 16 | global_acc: 59.071% | global_loss: 2.2980666160583496
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 17 | global_acc: 55.595% | global_loss: 2.2988979816436768
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 18 | global_acc: 51.524% | global_loss: 2.2995615005493164
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 19 | global_acc: 43.214% | global_loss: 2.3001418113708496
# 132/132 [==============================] - 1s 4ms/step
# comm_round: 20 | global_acc: 35.310% | global_loss: 2.3006415367126465
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 21 | global_acc: 31.643% | global_loss: 2.3010239601135254
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 22 | global_acc: 28.024% | global_loss: 2.3013460636138916
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 23 | global_acc: 25.381% | global_loss: 2.3016018867492676
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 24 | global_acc: 25.119% | global_loss: 2.301816940307617
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 25 | global_acc: 22.024% | global_loss: 2.3019795417785645
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 26 | global_acc: 22.500% | global_loss: 2.3021113872528076
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 27 | global_acc: 19.000% | global_loss: 2.302213191986084
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 28 | global_acc: 13.310% | global_loss: 2.3022897243499756
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 29 | global_acc: 11.000% | global_loss: 2.3023521900177
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 30 | global_acc: 10.952% | global_loss: 2.302396059036255
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 31 | global_acc: 10.952% | global_loss: 2.3024275302886963
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 32 | global_acc: 10.952% | global_loss: 2.3024516105651855
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 33 | global_acc: 10.952% | global_loss: 2.302473545074463
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 34 | global_acc: 10.952% | global_loss: 2.3024940490722656
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 35 | global_acc: 10.952% | global_loss: 2.3025014400482178
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 36 | global_acc: 10.952% | global_loss: 2.3025095462799072
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 37 | global_acc: 10.952% | global_loss: 2.3025152683258057
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 38 | global_acc: 10.952% | global_loss: 2.3025176525115967
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 39 | global_acc: 10.952% | global_loss: 2.3025283813476562
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 40 | global_acc: 10.952% | global_loss: 2.302530288696289
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 41 | global_acc: 10.952% | global_loss: 2.302532911300659
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 42 | global_acc: 10.952% | global_loss: 2.3025386333465576
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 43 | global_acc: 10.952% | global_loss: 2.302537202835083
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 44 | global_acc: 10.952% | global_loss: 2.302534818649292
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 45 | global_acc: 10.952% | global_loss: 2.3025336265563965
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 46 | global_acc: 10.952% | global_loss: 2.3025336265563965
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 47 | global_acc: 10.952% | global_loss: 2.3025405406951904
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 48 | global_acc: 10.952% | global_loss: 2.302539110183716
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 49 | global_acc: 10.952% | global_loss: 2.302539348602295
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 50 | global_acc: 10.952% | global_loss: 2.3025383949279785
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 51 | global_acc: 10.952% | global_loss: 2.3025386333465576
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 52 | global_acc: 10.952% | global_loss: 2.30253529548645
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 53 | global_acc: 10.952% | global_loss: 2.3025381565093994
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 54 | global_acc: 10.952% | global_loss: 2.302537441253662
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 55 | global_acc: 10.952% | global_loss: 2.3025362491607666
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 56 | global_acc: 10.952% | global_loss: 2.302534818649292
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 57 | global_acc: 10.952% | global_loss: 2.30253529548645
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 58 | global_acc: 10.952% | global_loss: 2.302532434463501
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 59 | global_acc: 10.952% | global_loss: 2.302532434463501
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 60 | global_acc: 10.952% | global_loss: 2.302536725997925
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 61 | global_acc: 10.952% | global_loss: 2.30253529548645
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 62 | global_acc: 10.952% | global_loss: 2.302539587020874
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 63 | global_acc: 10.952% | global_loss: 2.3025410175323486
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 64 | global_acc: 10.952% | global_loss: 2.3025410175323486
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 65 | global_acc: 10.952% | global_loss: 2.302537441253662
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 66 | global_acc: 10.952% | global_loss: 2.3025386333465576
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 67 | global_acc: 10.952% | global_loss: 2.3025357723236084
# 132/132 [==============================] - 1s 6ms/step
# comm_round: 68 | global_acc: 10.952% | global_loss: 2.3025403022766113
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 69 | global_acc: 10.952% | global_loss: 2.3025405406951904
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 70 | global_acc: 10.952% | global_loss: 2.302537679672241
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 71 | global_acc: 10.952% | global_loss: 2.302541494369507
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 72 | global_acc: 10.952% | global_loss: 2.302542209625244
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 73 | global_acc: 10.952% | global_loss: 2.302542209625244
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 74 | global_acc: 10.952% | global_loss: 2.3025431632995605
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 75 | global_acc: 10.952% | global_loss: 2.302546977996826
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 76 | global_acc: 10.952% | global_loss: 2.3025453090667725
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 77 | global_acc: 10.952% | global_loss: 2.3025424480438232
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 78 | global_acc: 10.952% | global_loss: 2.3025431632995605
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 79 | global_acc: 10.952% | global_loss: 2.302541971206665
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 80 | global_acc: 10.952% | global_loss: 2.302544116973877
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 81 | global_acc: 10.952% | global_loss: 2.302546739578247
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 82 | global_acc: 10.952% | global_loss: 2.3025453090667725
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 83 | global_acc: 10.952% | global_loss: 2.3025450706481934
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 84 | global_acc: 10.952% | global_loss: 2.302544116973877
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 85 | global_acc: 10.952% | global_loss: 2.3025453090667725
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 86 | global_acc: 10.952% | global_loss: 2.302541494369507
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 87 | global_acc: 10.952% | global_loss: 2.3025400638580322
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 88 | global_acc: 10.952% | global_loss: 2.3025386333465576
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 89 | global_acc: 10.952% | global_loss: 2.302534818649292
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 90 | global_acc: 10.952% | global_loss: 2.302534341812134
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 91 | global_acc: 10.952% | global_loss: 2.30253529548645
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 92 | global_acc: 10.952% | global_loss: 2.302534580230713
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 93 | global_acc: 10.952% | global_loss: 2.3025357723236084
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 94 | global_acc: 10.952% | global_loss: 2.302534341812134
# 132/132 [==============================] - 1s 6ms/step
# comm_round: 95 | global_acc: 10.952% | global_loss: 2.3025386333465576
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 96 | global_acc: 10.952% | global_loss: 2.3025400638580322
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 97 | global_acc: 10.952% | global_loss: 2.3025333881378174
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 98 | global_acc: 10.952% | global_loss: 2.3025341033935547
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 99 | global_acc: 10.952% | global_loss: 2.3025357723236084
# 132/132 [==============================] - 1s 5ms/step
# comm_round: 100 | global_acc: 10.952% | global_loss: 2.302539587020874
# 0.1

# %%
x_axis = []
for i in range(100):
    x_axis.append(i+1)
plt.plot(x_axis, accuracies[0], color="blue")
plt.xlabel("Training round")
plt.ylabel("Accuracy")
plt.show()
plt.plot(x_axis, accuracies[1], color="red")
plt.xlabel("Training round")
plt.ylabel("Accuracy")
plt.show()
plt.plot(x_axis, accuracies[2], color="black")
plt.xlabel("Training round")
plt.ylabel("Accuracy")
plt.show()
plt.plot(x_axis, accuracies[3], color="green")
plt.xlabel("Training round")
plt.ylabel("Accuracy")
plt.show()
plt.plot(x_axis, accuracies[0], color="blue")
plt.plot(x_axis, accuracies[1], color="red")
plt.plot(x_axis, accuracies[2], color="black")
plt.plot(x_axis, accuracies[3], color="green")
plt.legend(["0%","1%","5%","10%"])
plt.xlabel("Training round")
plt.ylabel("Accuracy")
plt.show()
